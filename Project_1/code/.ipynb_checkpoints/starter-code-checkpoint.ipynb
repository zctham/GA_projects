# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# The “SAT or ACT?” problem has always plagued the minds of would-be college students. Coupled with the problem of poverty in the United States, there are serious issues of high achieving students not being able to proceed to college due to them coming from lower-income families.
#
# Hence, this project seeks to understand trends in the SAT and ACT tests for the years 2017 to 2019 and if household income level has an impact on participation rate and performance of these tests.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*

# %% [markdown]
# **The datasets used for analysis in this project are:**
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`UnemploymentReport.csv`](./data/UnemploymentReport.csv): 2019 Median Income by State
# * [`income_df_2017_2018.csv`](./data/income_df_2017_2018.csv): 2017 - 2018 Median Income by State

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# The following links are for states that have mandatory ACT or SAT requirements.

# %% [markdown]
# https://blog.prepscholar.com/which-states-require-the-sat
#
# https://blog.prepscholar.com/which-states-require-the-act-full-list-and-advice

# %% [markdown]
# **Scoring ranges per test:**
#
# 1. ACT range: 1 to 36 (composite score, from 4 compulsory sections (the writing section is optional), taken via a percentile approach against a general population; follows normal distribution
#
# 2. SAT range: 400 to 1600 (2 sections of range 200 to 800 each); follows normal distribution

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:

def mean(lst):
    mean = sum(lst) / len(lst)
    return mean

# %%
mean([1,2,3,4])
# Out:
# 2.5

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:               

def sd_dev(lst):
    a = 0
    for number in lst:
        a += (number - mean(lst))**2
    return (a /len(lst))**0.5

# %%
# Testing function

sd_dev([1,2,3,4])
# Out:
# 1.118033988749895

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:

def str_cleaner(string):
    return float(string.strip().replace('%',''))/100

# %%
# Testing function

str_cleaner('50.5%')
# Out:
# 0.505

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

# %%
# Install wikipedia

pip install wikipedia
# Out:
# ...
#
# ...

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# Code:

# Reading sat_2017 dataset

sat_2017 = pd.read_csv('../data/sat_2017.csv')

# Printing first 5 rows

sat_2017.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
# Check for missing values
sat_2017.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %% [markdown]
# No null values.

# %%
# Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).

# Maximum for both tests are 800, maximum for total is 1600.
#https://www.khanacademy.org/test-prep/sat/x0a8c2e5f:untitled-615/x0a8c2e5f:scoring-on-the-sat/a/scoring-on-the-redesigned-sat#:~:text=The%20SAT%20is%20scored%20out,800%2B800%2C%20or%201600.

sat_2017['Math'].sort_values()
# Out:
# 20     52
# 8     468
# 7     492
# 12    493
# 22    495
# 9     497
# 19    499
# 43    507
# 6     512
# 10    515
# 36    517
# 29    520
# 40    521
# 32    523
# 39    524
# 4     524
# 30    526
# 48    528
# 38    531
# 14    532
# 1     533
# 47    534
# 33    535
# 46    541
# 11    541
# 37    548
# 21    551
# 45    551
# 2     553
# 28    553
# 13    556
# 31    561
# 35    570
# 0     572
# 18    586
# 26    591
# 3     594
# 5     595
# 41    603
# 42    604
# 50    604
# 24    607
# 44    614
# 17    616
# 34    621
# 27    625
# 16    628
# 25    631
# 15    635
# 49    649
# 23    651
# Name: Math, dtype: int64

# %% [markdown]
# Problems with sat_2017 dataset:
#
# 1. Minimum value for 'Math' is 52. Upon cross referencing with dataset, value should be 524. We will be updating the correct value.

# %%
sat_2017.iloc[20,3] = 524

# %%
# Checking if changes are made
sat_2017.iloc[20,3]
# Out:
# 524

# %%
# Display the datatypes of each feature
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
# Fix any incorrect data types found

# Change the 'Participation' datatype from 'object' to 'float64' through str_cleaner function

sat_2017['Participation'] = sat_2017['Participation'].apply(lambda x:str_cleaner(x))

# %%
# Check if changes are made

sat_2017
# Out:
#                    State  Participation  Evidence-Based Reading and Writing  \
# 0                Alabama           0.05                                 593
# 1                 Alaska           0.38                                 547
# 2                Arizona           0.30                                 563
# 3               Arkansas           0.03                                 614
# 4             California           0.53                                 531
# 5               Colorado           0.11                                 606
# 6            Connecticut           1.00                                 530
# 7               Delaware           1.00                                 503
# 8   District of Columbia           1.00                                 482
# 9                Florida           0.83                                 520
# 10               Georgia           0.61                                 535
# ...

# %%
# Renaming columns to lowercase and shortening 'Evidence-Based Reading and Writing' and assigning it to new variable 'cleaned_sat_2017'

cleaned_sat_2017 = sat_2017.rename(columns = {'State':'state',
                           'Participation':'sat_participation',
                          'Evidence-Based Reading and Writing':'sat_ebrw',
                           'Math':'sat_math',
                           'Total':'sat_total'
                          })

# %%
# Include new column called 'Year' to indicate year of test

cleaned_sat_2017['year'] = 2017

# %%
cleaned_sat_2017.head()
# Out:
#         state  sat_participation  sat_ebrw  sat_math  sat_total  year
# 0     Alabama               0.05       593       572       1165  2017
# 1      Alaska               0.38       547       533       1080  2017
# 2     Arizona               0.30       563       553       1116  2017
# 3    Arkansas               0.03       614       594       1208  2017
# 4  California               0.53       531       524       1055  2017

# %%
cleaned_sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   state              51 non-null     object
#  1   sat_participation  51 non-null     float64
#  2   sat_ebrw           51 non-null     int64
#  3   sat_math           51 non-null     int64
#  4   sat_total          51 non-null     int64
#  5   year               51 non-null     int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 2.5+ KB

# %% [markdown]
# ### Drop unnecessary rows (if needed).
#
# None to drop in sat_2017.

# %%
# Reading sat_2018 dataset

sat_2018 = pd.read_csv('../data/sat_2018.csv')

# Printing first 5 rows

sat_2018.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
# Check for missing values
sat_2018.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
# Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
print(sat_2018['Evidence-Based Reading and Writing'].max())
print(sat_2018['Evidence-Based Reading and Writing'].min())
print(sat_2018['Math'].max())
print(sat_2018['Math'].min())
# Out:
# 643
# 480
# 655
# 480

# %% [markdown]
# No obvious issues noted with sat_2018 dataset.

# %%
# Display the datatypes of each feature
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
# Fix any incorrect data types found

# Change the 'Participation' datatype from 'object' to 'float64' through str_cleaner function

sat_2018['Participation'] = sat_2018['Participation'].apply(lambda x:str_cleaner(x))

# %%
# Check if changes are made

sat_2018
# Out:
#                    State  Participation  Evidence-Based Reading and Writing  \
# 0                Alabama           0.06                                 595
# 1                 Alaska           0.43                                 562
# 2                Arizona           0.29                                 577
# 3               Arkansas           0.05                                 592
# 4             California           0.60                                 540
# 5               Colorado           1.00                                 519
# 6            Connecticut           1.00                                 535
# 7               Delaware           1.00                                 505
# 8   District of Columbia           0.92                                 497
# 9                Florida           0.56                                 550
# 10               Georgia           0.70                                 542
# ...

# %%
# Renaming columns to lowercase and shortening 'Evidence-Based Reading and Writing' and assigning it to new variable

cleaned_sat_2018 = sat_2018.rename(columns = {'State':'state',
                           'Participation':'sat_participation',
                          'Evidence-Based Reading and Writing':'sat_ebrw',
                           'Math':'sat_math',
                           'Total':'sat_total'
                          })

# %%
# Include 'year' column to indicate year of test

cleaned_sat_2018['year'] = 2018

# %%
cleaned_sat_2018.head()
# Out:
#         state  sat_participation  sat_ebrw  sat_math  sat_total  year
# 0     Alabama               0.06       595       571       1166  2018
# 1      Alaska               0.43       562       544       1106  2018
# 2     Arizona               0.29       577       572       1149  2018
# 3    Arkansas               0.05       592       576       1169  2018
# 4  California               0.60       540       536       1076  2018

# %% [markdown]
# ### Drop unnecessary rows (if needed).
#
# None to drop in sat_2018.

# %%
# Reading sat_2019 dataset

sat_2019 = pd.read_csv('../data/sat_2019.csv')

# Printing first 5 rows

sat_2019.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
# Check for missing values
sat_2019.isnull().sum()
# Out:
# State                 0
# Participation Rate    0
# EBRW                  0
# Math                  0
# Total                 0
# dtype: int64

# %%
# Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
print(sat_2019['EBRW'].max())
print(sat_2019['EBRW'].min())
print(sat_2019['Math'].max())
print(sat_2019['Math'].min())
# Out:
# 636
# 483
# 648
# 445

# %%
# Difference noted in number of states between sat_2019 dataset and sat_2017, sat_2018 dataset, namely 'Puerto Rico' and 'Virgin Islands'

print('Number of states in 2018:',len(sat_2019['State']))
print('Number of states in 2018:',len(cleaned_sat_2018['state']))

[x for x in sat_2019['State'].to_list() if x not in sat_2018['State'].to_list()]
# Out:
# Number of states in 2018: 53
# Number of states in 2018: 51
# ['Puerto Rico', 'Virgin Islands']

# %% [markdown]
# According to https://www.saj.usace.army.mil/Media/News-Stories/Article/479601/the-relationship-between-the-united-states-puerto-rico-and-the-us-virgin-islands/#:~:text=Both%20Puerto%20Rico%20and%20the,other%20territories%20without%20a%20passport., Puerto Rico and Virgin Islands are unincorporated territories instead of 'states' in the US.They also have null participation rates. As such, we will be removing them from the data.

# %%
sat_2019 = sat_2019[(sat_2019['State'] != 'Puerto Rico') & (sat_2019['State'] != 'Virgin Islands')]

# %%
# Display the datatypes of each feature
sat_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               51 non-null     object
#  1   Participation Rate  51 non-null     object
#  2   EBRW                51 non-null     int64
#  3   Math                51 non-null     int64
#  4   Total               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.4+ KB

# %%
# Fix any incorrect data types found

# Change the 'Participation' datatype from 'object' to 'float64' through str_cleaner function

sat_2019['Participation Rate'] = sat_2019['Participation Rate'].apply(lambda x:str_cleaner(x))

# %%
# Renaming columns to lowercase and assigning it to new variable 'cleaned_sat_2019'

cleaned_sat_2019 = sat_2019.rename(columns = {'State':'state',
                           'Participation Rate':'sat_participation',
                          'EBRW':'sat_ebrw',
                           'Math':'sat_math',
                           'Total':'sat_total'
                          })
# Reset Index
cleaned_sat_2019 = cleaned_sat_2019.reset_index(drop = True)

# %%
cleaned_sat_2019
# Out:
#                    state  sat_participation  sat_ebrw  sat_math  sat_total
# 0                Alabama               0.07       583       560       1143
# 1                 Alaska               0.41       556       541       1097
# 2                Arizona               0.31       569       565       1134
# 3               Arkansas               0.06       582       559       1141
# 4             California               0.63       534       531       1065
# 5               Colorado               1.00       518       506       1024
# 6            Connecticut               1.00       529       516       1046
# 7               Delaware               1.00       499       486        985
# 8   District of Columbia               0.94       495       480        975
# 9                Florida               1.00       516       483        999
# 10               Georgia               0.71       538       519       1058
# ...

# %%
cleaned_sat_2019['year'] = 2019

# %%
cleaned_sat_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   state              51 non-null     object
#  1   sat_participation  51 non-null     float64
#  2   sat_ebrw           51 non-null     int64
#  3   sat_math           51 non-null     int64
#  4   sat_total          51 non-null     int64
#  5   year               51 non-null     int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 2.5+ KB

# %%
# Code:

# Reading act_2017 dataset

act_2017 = pd.read_csv('../data/act_2017.csv')

# Printing first 5 rows

display(act_2017.head())
display(act_2017.tail())
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4
#             State Participation  English  Math  Reading  Science Composite
# 47       Virginia           29%     23.5  23.3     24.6     23.5      23.8
# 48     Washington           29%     20.9  21.9     22.1     22.0      21.9
# 49  West Virginia           69%     20.0  19.4     21.2     20.5      20.4
# 50      Wisconsin          100%     19.7  20.4     20.6     20.9      20.5
# 51        Wyoming          100%     19.4  19.8     20.8     20.6     20.2x

# %%
# Checking for missing values

act_2017.isnull().sum()
# Out:
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64

# %%
# Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).

# https://www.crimsoneducation.org/sg/blog/test-prep/good-ACT-score/
# ACT test scores range from 1 to 36, 'Composite' being the average of the 4 subjects (English, Math, Reading, Science)

print(act_2017['English'].max())
print(act_2017['English'].min())
print(act_2017['Math'].max())
print(act_2017['Math'].min())
print(act_2017['Reading'].max())
print(act_2017['Reading'].min())
print(act_2017['Science'].max())
print(act_2017['Science'].min())
print(act_2017['Composite'].max())
print(act_2017['Composite'].min())
# Out:
# 25.5
# 16.3
# 25.3
# 18.0
# 26.0
# 18.1
# 24.9
# 2.3
# 25.5
# 17.8

# %% [markdown]
# Found errors in the 'Science' value for Maryland. Upon cross referencing with data source, value should be 23.8. There is also a 'National' value in the 'State' column, which should be removed as we are only looking at state level.

# %%
#Checking for index of row with error

act_2017['Science']
# Out:
# 0     21.0
# 1     19.4
# 2     19.9
# 3     19.8
# 4     19.5
# 5     22.2
# 6     20.9
# 7     24.6
# 8     23.6
# 9     23.5
# 10    19.4
# 11    21.3
# 12    19.3
# 13    22.1
# 14    21.3
# 15    22.3
# 16    22.1
# 17    21.7
# 18    20.1
# 19    19.6
# 20    23.7
# 21     2.3
# 22    24.7
# 23    23.8
# 24    21.6
# 25    18.8
# 26    20.5
# 27    20.5
# 28    21.5
# 29    18.2
# 30    24.9
# 31    23.2
# 32    20.0
# 33    23.9
# 34    19.3
# 35    20.6
# 36    22.0
# 37    19.6
# 38    21.7
# 39    23.3
# 40    23.4
# 41    18.9
# 42    22.0
# 43    19.9
# 44    20.9
# 45    20.6
# 46    23.2
# 47    23.5
# 48    22.0
# 49    20.5
# 50    20.9
# 51    20.6
# Name: Science, dtype: float64

# %%
# Changing error value to 23.8

act_2017.loc[21,'Science'] = 23.8

# %%
# Check that change is made

act_2017[act_2017['State'] == 'Maryland']
# Out:
#        State Participation  English  Math  Reading  Science Composite
# 21  Maryland           28%     23.3  23.1     24.2     23.8      23.6

# %%
# Removing row with 'National' State 

act_2017 = act_2017[act_2017['State'] != 'National']

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 1 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          51 non-null     object
#  1   Participation  51 non-null     object
#  2   English        51 non-null     float64
#  3   Math           51 non-null     float64
#  4   Reading        51 non-null     float64
#  5   Science        51 non-null     float64
#  6   Composite      51 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.2+ KB

# %% [markdown]
# Noted 'Composite' value for Wyoming is 20.2x, causing the column to be object Dtype. To remove 'x' and change column type to float64. Additionally, apply str_cleaner function to 'Participation column.

# %%
# Wyoming is at the 51st index, hence use .loc to change value

act_2017.loc[51,'Composite'] = 20.2

act_2017['Composite'] = act_2017['Composite'].astype('float64')

# %%
# Check that changes are made

act_2017[act_2017['State'] == 'Wyoming']
# Out:
#       State Participation  English  Math  Reading  Science  Composite
# 51  Wyoming          100%     19.4  19.8     20.8     20.6       20.2

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 1 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          51 non-null     object
#  1   Participation  51 non-null     object
#  2   English        51 non-null     float64
#  3   Math           51 non-null     float64
#  4   Reading        51 non-null     float64
#  5   Science        51 non-null     float64
#  6   Composite      51 non-null     float64
# dtypes: float64(5), object(2)
# memory usage: 5.2+ KB

# %%
# Changing data type of 'Participation' to float64

act_2017['Participation'] = act_2017['Participation'].apply(lambda x:str_cleaner(x))

act_2017['Participation'] = act_2017['Participation'].astype('float64')

# %%
act_2017
# Out:
#                    State  Participation  English  Math  Reading  Science  \
# 1                Alabama           1.00     18.9  18.4     19.7     19.4
# 2                 Alaska           0.65     18.7  19.8     20.4     19.9
# 3                Arizona           0.62     18.6  19.8     20.1     19.8
# 4               Arkansas           1.00     18.9  19.0     19.7     19.5
# 5             California           0.31     22.5  22.7     23.1     22.2
# 6               Colorado           1.00     20.1  20.3     21.2     20.9
# 7            Connecticut           0.31     25.5  24.6     25.6     24.6
# 8               Delaware           0.18     24.1  23.4     24.8     23.6
# 9   District of Columbia           0.32     24.4  23.5     24.9     23.5
# 10               Florida           0.73     19.0  19.4     21.0     19.4
# 11               Georgia           0.55     21.0  20.9     22.0     21.3
# 12                Hawaii           0.90     17.8  19.2     19.2     19.3
# ...

# %%
# Renaming columns to lowercase and assigning it to new dataframe

cleaned_act_2017 = act_2017.rename(columns = {'State':'state',
                           'Participation':'act_participation',
                          'English':'act_english',
                           'Math':'act_math',
                            'Reading':'act_reading',
                            'Science':'act_science',
                           'Composite':'act_composite'
                          })

# %%
# Include year to indicate year of test

cleaned_act_2017['year'] = 2017

# %%
cleaned_act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 1 to 51
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   state              51 non-null     object
#  1   act_participation  51 non-null     float64
#  2   act_english        51 non-null     float64
#  3   act_math           51 non-null     float64
#  4   act_reading        51 non-null     float64
#  5   act_science        51 non-null     float64
#  6   act_composite      51 non-null     float64
#  7   year               51 non-null     int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 5.6+ KB

# %%
# Code:

# Reading act_2018 dataset

act_2018 = pd.read_csv('../data/act_2018.csv')

# Printing first 5 rows

display(act_2018.head())
display(act_2018.tail())
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7
#             State Participation  Composite
# 47       Virginia           24%       23.9
# 48     Washington           24%       22.2
# 49  West Virginia           65%       20.3
# 50      Wisconsin          100%       20.5
# 51        Wyoming          100%       20.0

# %%
# Checking for missing values

act_2018.isnull().sum()
# Out:
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %% [markdown]
# Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
#
# Errors noted:
# 1. Duplicate copies of Maine state
# 2. Missing values of the 4 subjects, we will populate it based on datasets sourced externally.
# https://nces.ed.gov/programs/digest/d18/tables/dt18_226.60.asp
# 3. 'Participation' not in float value
# 4. 'District of columbia' should be 'District of Columbia'.

# %%
# Remove duplicate of Maine State

act_2018.drop_duplicates(inplace = True)

# %%
# Renaming 'District of Columbia'

act_2018.loc[[8],['State']] = 'District of Columbia'

# %%
# Check that changes are done

act_2018[8:9]
# Out:
#                   State Participation  Composite
# 8  District of Columbia           32%       23.6

# %%
act_2018.reset_index(drop = True)
# Out:
#                    State Participation  Composite
# 0                Alabama          100%       19.1
# 1                 Alaska           33%       20.8
# 2                Arizona           66%       19.2
# 3               Arkansas          100%       19.4
# 4             California           27%       22.7
# 5               Colorado           30%       23.9
# 6            Connecticut           26%       25.6
# 7               Delaware           17%       23.8
# 8   District of Columbia           32%       23.6
# 9                Florida           66%       19.9
# 10               Georgia           53%       21.4
# 11                Hawaii           89%       18.9
# 12                 Idaho           36%       22.3
# 13              Illinois           43%       23.9
# 14               Indiana           32%       22.5
# 15                  Iowa           68%       21.8
# 16                Kansas           71%       21.6
# 17              Kentucky          100%       20.2
# ...

# %%
# Populate missing values from externally sourced data

act_english_2018 = ['18.9','19.8','18.2','19.1','22.5','23.9','26','23.7','23.7','19.2','20.9','18.2','21.9','24.1','21.9','21.0','21.0','19.9','19.0','23.8','22.1','25.5','24.5','20.2','18.2','19.5','18.7','19.4','16.6','25.1','23.8','18.3','24.2','18.0','19.1','19.3','18.4','20.6','23.3','24.4','17.3','20.8','19.4','19.6','19.7','23.9','23.8','21.4','19.8','19.8','19.0']
act_math_2018 = ['18.3','20.6','19.4','18.9','22.5','23.2','24.8','23.1','22.7','19.3','20.7','19','21.6','23.4','22.3','21.2','21.1','19.7','18.5','23.6','22.0','25.2','23.9','21.4','18.1','19.7','19.9','19.8','17.8','24.7','23.6','19.1','24.2','19.3','20.3','20.3','18.8','20.9','23.2','23.6','18.2','21.6','19.1','20.6','19.9','23.4','23.3','22.2','19.4','20.3','19.7']
act_reading_2018 = ['19.6','21.6','19.5','19.7','23','24.4','26.1','24.5','24.4','21.1','22.1','19.1','23.2','24.2','23.1','22.5','22.3','20.8','19.6','24.7','23.1','25.9','24.7','21.7','18.9','20.5','20.7','20.4','18','25.6','24','20.1','24.9','19.5','20.7','20.8','20.1','21.9','24','25','18.6','22.4','19.9','21.1','20.9','24.9','24.7','22.7','21.3','20.6','20.6']
act_science_2018 = ['19.0','20.7','19.2','19.4','22.1','23.5','24.9','23.4','23.0','19.5','21.2','19.0','22.1','23.4','22.2','22.0','21.5','20.1','19.1','23.4','22.2','24.7','23.9','21.4','18.6','20.0','20.0','20.1','17.9','24.4','23.0','19.7','24.2','19.2','20.5','20.4','19.4','21.1','23.1','23.5','18.5','22.2','19.6','20.8','20.5','23.8','23.5','22.0','20.4','20.8','20.3']

act_2018['act_english'] = act_english_2018
act_2018['act_math'] = act_math_2018
act_2018['act_reading'] = act_reading_2018
act_2018['act_science'] = act_science_2018

act_2018['act_english'] = act_2018['act_english'].astype('float64')
act_2018['act_math'] = act_2018['act_math'].astype('float64')
act_2018['act_reading'] = act_2018['act_reading'].astype('float64')
act_2018['act_science'] = act_2018['act_science'].astype('float64')

# %%
# Change data type of 'Participation' to float64

act_2018['Participation'] = act_2018['Participation'].apply(lambda x:str_cleaner(x))

act_2018['Participation'] = act_2018['Participation'].astype('float64')

# %%
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          51 non-null     object
#  1   Participation  51 non-null     float64
#  2   Composite      51 non-null     float64
#  3   act_english    51 non-null     float64
#  4   act_math       51 non-null     float64
#  5   act_reading    51 non-null     float64
#  6   act_science    51 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 5.2+ KB

# %%
# Rename columns to lowercase and include year

act_2018 = act_2018.rename(columns = {'Participation':'act_participation',
                                   'State':'state',
                                   'Composite':'act_composite'})

# %%
#Re-arrange columns

cleaned_act_2018 = act_2018[['state','act_participation','act_english','act_math','act_reading','act_science','act_composite']]
cleaned_act_2018.head()
# Out:
#         state  act_participation  act_english  act_math  act_reading  \
# 0     Alabama               1.00         18.9      18.3         19.6
# 1      Alaska               0.33         19.8      20.6         21.6
# 2     Arizona               0.66         18.2      19.4         19.5
# 3    Arkansas               1.00         19.1      18.9         19.7
# 4  California               0.27         22.5      22.5         23.0
#
#    act_science  act_composite
# 0         19.0           19.1
# 1         20.7           20.8
# 2         19.2           19.2
# 3         19.4           19.4
# 4         22.1           22.7

# %%
cleaned_act_2018['year'] = 2018
# Out:
# <ipython-input-68-07ec6a01da5f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_act_2018['year'] = 2018

# %%
cleaned_act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 51
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   state              51 non-null     object
#  1   act_participation  51 non-null     float64
#  2   act_english        51 non-null     float64
#  3   act_math           51 non-null     float64
#  4   act_reading        51 non-null     float64
#  5   act_science        51 non-null     float64
#  6   act_composite      51 non-null     float64
#  7   year               51 non-null     int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 5.6+ KB

# %%
# Code:

# Reading act_2019 dataset

act_2019 = pd.read_csv('../data/act_2019.csv')

# Printing first 5 rows

display(act_2019.head())
display(act_2019.tail())
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6
#             State Participation  Composite
# 47     Washington           24%       22.1
# 48  West Virginia           49%       20.8
# 49      Wisconsin          100%       20.3
# 50        Wyoming          100%       19.8
# 51       National           52%       20.7

# %%
# Checking for missing values

act_2019.isnull().sum()
# Out:
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %% [markdown]
# Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
#
# Errors noted:
# 1. 'National' value in state column. We will remove it as it represents data for the nation of US.
# 2. Missing values of the 4 subjects, we will populate it based on datasets sourced externally.
# https://nces.ed.gov/programs/digest/d19/tables/dt19_226.60.asp
# 3. 'Participation' not in float value

# %%
# Remove row with 'National' State

act_2019 = act_2019[act_2019['State'] != 'National']

# %%
# Populate missing data with externally sourced data

act_english_2019 = ['18.7','18.9','17.9','19','22.4','23.8','25.9','23.9','23.6','19.5','20.9','17.9','21.9','24.5','21.7','20.8','20.5','19.5','18.7','24.2','22','25.5','24.5','20.3','18.1','20.3','18.7','19.4','16.8','24.9','24.3','18.1','24.1','17.8','18.6','19','18.2','20.3','23.3','25','18','20.7','19.1','19.5','19.5','23.9','23.8','21.3','20.6','19.4','18.8']
act_math_2019 = ['18.1','19.9','19.2','18.7','22.3','23.3','24.7','23.1','22.7','19.5','20.7','19.2','21.9','23.8','22.3','21','20.7','19.2','18.2','23.8','21.7','25.2','24','21.4','17.9','20.2','19.7','19.7','18','24.7','24','18.9','24.1','19.2','19.9','19.9','18.3','20.8','23.1','23.9','18.7','21.3','18.9','20.4','20','23.3','23.3','22.1','19.7','20.2','19.4']
act_reading_2019 = ['19.5','20.9','19.3','19.6','23','24.3','26.1','24.7','24.4','21.2','22.2','19.2','23.4','24.7','23.1','22.3','21.8','20.5','19.2','25.1','23.1','26.1','24.8','21.7','18.9','21.3','20.6','20.3','18.2','25.6','24.6','20','25','19.4','20.3','20.5','19.6','21.7','24.1','25.5','19.4','22.2','19.7','21.1','20.8','25','24.8','22.7','21.7','20.4','20.4']
act_science_2019 = ['18.8','20.2','19','19.2','22.2','23.4','24.8','23.5','22.9','19.7','21.2','19.2','22.2','23.7','22.2','21.8','21.1','19.6','18.8','23.7','22.1','24.8','24','21.6','18.4','20.8','19.9','20.2','17.9','24.5','23.6','19.6','24.4','19','20.2','20.1','19','21.1','23.2','24','18.9','21.9','19.2','20.6','20.3','23.9','23.6','21.9','20.7','20.6','20']

act_2019['act_english'] = act_english_2019
act_2019['act_math'] = act_math_2019
act_2019['act_reading'] = act_reading_2019
act_2019['act_science'] = act_science_2019

act_2019['act_english'] = act_2019['act_english'].astype('float64')
act_2019['act_math'] = act_2019['act_math'].astype('float64')
act_2019['act_reading'] = act_2019['act_reading'].astype('float64')
act_2019['act_science'] = act_2019['act_science'].astype('float64')

# %%
# Change data type of 'Participation' to float64

act_2019['Participation'] = act_2019['Participation'].apply(lambda x:str_cleaner(x))

act_2019['Participation'] = act_2019['Participation'].astype('float64')

# %%
# Rename columns to lowercase and include year

act_2019 = act_2019.rename(columns = {'Participation':'act_participation',
                                   'State':'state',
                                   'Composite':'act_composite'})

# %%
# Re-arrange columns

cleaned_act_2019 = act_2019[['state','act_participation','act_english','act_math','act_reading','act_science','act_composite']]
cleaned_act_2019.head()
# Out:
#         state  act_participation  act_english  act_math  act_reading  \
# 0     Alabama               1.00         18.7      18.1         19.5
# 1      Alaska               0.38         18.9      19.9         20.9
# 2     Arizona               0.73         17.9      19.2         19.3
# 3    Arkansas               1.00         19.0      18.7         19.6
# 4  California               0.23         22.4      22.3         23.0
#
#    act_science  act_composite
# 0         18.8           18.9
# 1         20.2           20.1
# 2         19.0           19.0
# 3         19.2           19.3
# 4         22.2           22.6

# %%
cleaned_act_2019['year'] = 2019
# Out:
# <ipython-input-77-0525a928fe9a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_act_2019['year'] = 2019

# %%
cleaned_act_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   state              51 non-null     object
#  1   act_participation  51 non-null     float64
#  2   act_english        51 non-null     float64
#  3   act_math           51 non-null     float64
#  4   act_reading        51 non-null     float64
#  5   act_science        51 non-null     float64
#  6   act_composite      51 non-null     float64
#  7   year               51 non-null     int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 3.6+ KB

# %%
# Merge SAT dataframes

sat_df = pd.concat(objs = [cleaned_sat_2017,cleaned_sat_2018,cleaned_sat_2019],axis = 0, ignore_index = True)

# %%
sat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   state              153 non-null    object
#  1   sat_participation  153 non-null    float64
#  2   sat_ebrw           153 non-null    int64
#  3   sat_math           153 non-null    int64
#  4   sat_total          153 non-null    int64
#  5   year               153 non-null    int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 7.3+ KB

# %%
# Merge ACT dataframes

# %%
act_df = pd.concat(objs = [cleaned_act_2017,cleaned_act_2018,cleaned_act_2019],axis = 0, ignore_index = True)

# %%
act_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   state              153 non-null    object
#  1   act_participation  153 non-null    float64
#  2   act_english        153 non-null    float64
#  3   act_math           153 non-null    float64
#  4   act_reading        153 non-null    float64
#  5   act_science        153 non-null    float64
#  6   act_composite      153 non-null    float64
#  7   year               153 non-null    int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 9.7+ KB

# %% [markdown]
# To have a look at median income across states, I will be bringing in externally sourced data giving median income levels across states in the US for Year 2017 to 2019.
#
# https://data.ers.usda.gov/reports.aspx?ID=17828
# https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_income

# %%
income_df_2019 = pd.read_csv('../data/UnemploymentReport.csv',header = [1])

# %%
income_df_2019
# Out:
#                                                 FIPS                   Name  \
# 0                                               01000               Alabama
# 1                                               02000                Alaska
# 2                                               04000               Arizona
# 3                                               05000              Arkansas
# 4                                               06000            California
# 5                                               08000              Colorado
# 6                                               09000           Connecticut
# 7                                               10000              Delaware
# 8                                               11000  District of Columbia
# 9                                               12000               Florida
# 10                                              13000               Georgia
# ...

# %%
# Check null rows and rows with States not found in SAT data

[x for x in income_df_2019['Name'].to_list() if x not in cleaned_sat_2019['state'].to_list()]
# Out:
# ['Puerto Rico', nan, nan]

# %%
# We only need the states name and median income household columns

income_df_2019 = income_df_2019[['Name','Median Household Income (2019)']]

# %%
income_df_2019
# Out:
#                     Name Median Household Income (2019)
# 0                Alabama                        $51,771
# 1                 Alaska                        $77,203
# 2                Arizona                        $62,027
# 3               Arkansas                        $49,020
# 4             California                        $80,423
# 5               Colorado                        $77,104
# 6            Connecticut                        $78,920
# 7               Delaware                        $70,348
# 8   District of Columbia                        $90,395
# 9                Florida                        $59,198
# 10               Georgia                        $61,950
# 11                Hawaii                        $83,734
# 12                 Idaho                        $60,830
# 13              Illinois                        $69,212
# 14               Indiana                        $57,617
# 15                  Iowa                        $61,807
# ...

# %%
# Drop the last 3 rows for state of 'Puerto Rico' and NaN values
income_df_2019 = income_df_2019.iloc[:51]

# Include year column to indicate year
income_df_2019['year'] = 2019

# Rename columns
income_df_2019 = income_df_2019.rename(columns = {'Name':'state',
                           'Median Household Income (2019)':'median_income'})
# Out:
# <ipython-input-89-062dc8086d38>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   income_df_2019['year'] = 2019

# %%
# Clean median_income column to show integer

def cleaner(string):
    return float(string.strip().replace('$','').replace(',',''))

income_df_2019['median_income'] = income_df_2019['median_income'].apply(lambda x:cleaner(x))

# %%
# Re arranging columns

income_df_2019 = income_df_2019[['state','year','median_income']]

# %%
# Bringing in 2017 to 2018 data on US median income by states and territories
# https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_income

import wikipedia as wp

html = wp.page('List of U.S. states and territories by income').html().encode("UTF-8")
income_df_2017_2018 = pd.read_html(html)[1]
income_df_2017_2018.head()
# Out:
#   Rank State or territory     2018     2017     2016     2015 2014[note 2]
# 0    1   Washington, D.C.  $85,203  $82,372  $75,506  $75,628      $71,648
# 1    2           Maryland  $83,242  $80,776  $78,945  $75,847      $73,971
# 2    3         New Jersey  $81,740  $80,088  $76,126  $72,222      $71,919
# 3    4             Hawaii  $80,212  $77,765  $74,511  $73,486      $69,592
# 4    5      Massachusetts  $79,835  $77,385  $75,297  $70,628      $69,160

# %%
# Saving out new csv of 2017 - 2018 median income data

income_df_2017_2018.to_csv('../data/income_df_2017_2018.csv', index = False)

# %%
# Checking what States are in the data

income_df_2017_2018.sort_values('State or territory')
# Out:
#    Rank        State or territory     2018     2017     2016     2015  \
# 46   46                   Alabama  $49,861  $48,123  $46,257  $44,765
# 8     9                    Alaska  $74,346  $73,181  $76,440  $73,355
# 54   54            American Samoa      â      â      â      â
# 28   28                   Arizona  $59,246  $56,581  $53,558  $51,492
# 50   50                  Arkansas  $47,062  $45,869  $44,334  $41,995
# 6     7                California  $75,277  $71,805  $67,739  $64,500
# 11   12                  Colorado  $71,953  $69,117  $65,685  $63,909
# 5     6               Connecticut  $76,348  $74,168  $73,433  $71,346
# 16   17                  Delaware  $64,805  $62,852  $61,757  $61,255
# 38   38                   Florida  $55,462  $52,594  $50,860  $49,426
# 29   29                   Georgia  $58,756  $56,183  $53,559  $51,244
# 47   47                      Guam      â      â      â      â
# ...

# %%
# Remove values for 'American Samoa','Guam','Northern Mariana Islands','Virgin Islands','Puerto Rico','United States',
# as these locations are not states of the USA and change state of 'Washington D.C' to 'District of Columbia'

income_df_2017_2018.drop([20,54,47,55,56,53],inplace = True)

# %%
income_df_2017_2018[:1]['State or territory'] = 'District of Columbia'
# Out:
# <ipython-input-96-0e5ae11dd2eb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   income_df_2017_2018[:1]['State or territory'] = 'District of Columbia'

# %%
# Sort value by 'State or territory' for joining with 2019 income data and reset index

income_df_2017_2018 = income_df_2017_2018.sort_values('State or territory').reset_index(drop = True)

# %%
# Check for any differences in State between 2017,2018 and 2019 income data

print([state for state in income_df_2017_2018['State or territory'] if state in income_df_2019['state']])
print([state for state in income_df_2019['state'] if state in income_df_2017_2018['State or territory']])
# Out:
# []
# []

# %%
# Take in only columns for 2018 and 2017 data

income_df_2017_2018 = income_df_2017_2018[['State or territory','2018','2017']]

# %%
# Melting dataframe from long to wide to join with 2019 data

income_df_2017_2018 = pd.melt(income_df_2017_2018, id_vars=['State or territory'])

# %%
# Check data after melting

income_df_2017_2018
# Out:
#     State or territory variable    value
# 0              Alabama     2018  $49,861
# 1               Alaska     2018  $74,346
# 2              Arizona     2018  $59,246
# 3             Arkansas     2018  $47,062
# 4           California     2018  $75,277
# ..                 ...      ...      ...
# 97            Virginia     2017  $71,535
# 98          Washington     2017  $70,979
# 99       West Virginia     2017  $43,469
# 100          Wisconsin     2017  $59,305
# 101            Wyoming     2017  $60,434
#
# [102 rows x 3 columns]

# %%
# Rename columns to merge with 2019 income data and clean income column to remove '$' and ','

income_df_2017_2018 = income_df_2017_2018.rename(columns = {'State or territory':'state',
                                                           'variable':'year',
                                                            'value':'median_income'})

income_df_2017_2018['median_income'] = income_df_2017_2018['median_income'].apply(lambda x:cleaner(x))

income_df_2017_2018['year'] = income_df_2017_2018['year'].astype('int64')

# %%
income_df_2017_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          102 non-null    object
#  1   year           102 non-null    int64
#  2   median_income  102 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.5+ KB

# %%
income_df_2017_2018
# Out:
#              state  year  median_income
# 0          Alabama  2018        49861.0
# 1           Alaska  2018        74346.0
# 2          Arizona  2018        59246.0
# 3         Arkansas  2018        47062.0
# 4       California  2018        75277.0
# ..             ...   ...            ...
# 97        Virginia  2017        71535.0
# 98      Washington  2017        70979.0
# 99   West Virginia  2017        43469.0
# 100      Wisconsin  2017        59305.0
# 101        Wyoming  2017        60434.0
#
# [102 rows x 3 columns]

# %%
# Concat 2019 median income data with 2017-2018 median income data

income_df = pd.concat(objs = [income_df_2019,income_df_2017_2018], axis = 0)

# %%
income_df
# Out:
#              state  year  median_income
# 0          Alabama  2019        51771.0
# 1           Alaska  2019        77203.0
# 2          Arizona  2019        62027.0
# 3         Arkansas  2019        49020.0
# 4       California  2019        80423.0
# ..             ...   ...            ...
# 97        Virginia  2017        71535.0
# 98      Washington  2017        70979.0
# 99   West Virginia  2017        43469.0
# 100      Wisconsin  2017        59305.0
# 101        Wyoming  2017        60434.0
#
# [153 rows x 3 columns]

# %% [markdown]
# ### Merge SAT and ACT data into 'Combined' dataframe

# %%
# Merge SAT and ACT data

combined = pd.merge(left = sat_df,
        right = act_df,
        on = ['state','year'])

# %%
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 153 entries, 0 to 152
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   state              153 non-null    object
#  1   sat_participation  153 non-null    float64
#  2   sat_ebrw           153 non-null    int64
#  3   sat_math           153 non-null    int64
#  4   sat_total          153 non-null    int64
#  5   year               153 non-null    int64
#  6   act_participation  153 non-null    float64
#  7   act_english        153 non-null    float64
#  8   act_math           153 non-null    float64
#  9   act_reading        153 non-null    float64
#  10  act_science        153 non-null    float64
#  11  act_composite      153 non-null    float64
# dtypes: float64(7), int64(4), object(1)
# memory usage: 15.5+ KB

# %% [markdown]
# ### Merge 'combined' and 'income_df' into 'final' dataframe

# %%
final = pd.merge(left = combined,
                right = income_df,
                on = ['state','year'])

# %%
# Inspect the data after merging

display(final.shape)
display(final.info())
# Out:
# (153, 13)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 153 entries, 0 to 152
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   state              153 non-null    object
#  1   sat_participation  153 non-null    float64
#  2   sat_ebrw           153 non-null    int64
#  3   sat_math           153 non-null    int64
#  4   sat_total          153 non-null    int64
#  5   year               153 non-null    int64
#  6   act_participation  153 non-null    float64
#  7   act_english        153 non-null    float64
#  8   act_math           153 non-null    float64
#  9   act_reading        153 non-null    float64
#  10  act_science        153 non-null    float64
#  11  act_composite      153 non-null    float64
#  12  median_income      153 non-null    float64
# dtypes: float64(8), int64(4), object(1)
# memory usage: 16.7+ KB
# None

# %%
# Re-arranging 'year' column to second column

final = final[['state','year','sat_participation','sat_ebrw','sat_math','sat_total','act_participation','act_english',
              'act_math','act_reading','act_science','act_composite','median_income']]

final
# Out:
#              state  year  sat_participation  sat_ebrw  sat_math  sat_total  \
# 0          Alabama  2017               0.05       593       572       1165
# 1           Alaska  2017               0.38       547       533       1080
# 2          Arizona  2017               0.30       563       553       1116
# 3         Arkansas  2017               0.03       614       594       1208
# 4       California  2017               0.53       531       524       1055
# ..             ...   ...                ...       ...       ...        ...
# 148       Virginia  2019               0.68       567       551       1119
# 149     Washington  2019               0.70       539       535       1074
# 150  West Virginia  2019               0.99       483       460        943
# 151      Wisconsin  2019               0.03       635       648       1283
# 152        Wyoming  2019               0.03       623       615       1238
#
# ...

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|2017 - 2019 ACT/SAT datasets|State names of the 50 states in the US |
# |year|int|2017 - 2019 ACT/SAT datasets |Year of occurrence of SAT/ACT/median income|
# |sat_participation|float|2017 - 2019 SAT dataset |Participation rate of states for SAT |
# |sat_ebrw|int|2017 - 2019 SAT dataset |Score of Evidence-based Reading and Writing (SAT)|
# |sat_math|int|2017 - 2019 SAT dataset |Score of Math (SAT)|
# |sat_total|int|2017 - 2019 SAT dataset |Total score of EBRW and Math (SAT)|
# |act_participation|float|2017 - 2019 ACT dataset |Participation rate of states for ACT |
# |act_english|float|2017 - 2019 ACT dataset |Score of English (ACT)|
# |act_math|float|2017 - 2019 ACT dataset |Score of Math (ACT)|
# |act_reading|float|2017 - 2019 ACT dataset |Score of Reading (ACT)|
# |act_science|float|2017 - 2019 ACT dataset |Score of Science (ACT)|
# |act_composite|float|2017 - 2019 ACT dataset |Average score of combined scores of 4 subjects (ACT)|
# |median income|float|2017 - 2019 ACT dataset |Median income of states in the US |

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2018, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
# Summary Statistics

final.describe().T
# Out:
#                    count          mean           std       min       25%  \
# year               153.0   2018.000000      0.819178   2017.00   2017.00
# sat_participation  153.0      0.448693      0.370944      0.02      0.04
# sat_ebrw           153.0    564.535948     46.301362    480.00    531.00
# sat_math           153.0    555.104575     48.485370    460.00    521.00
# sat_total          153.0   1119.732026     94.162654    943.00   1053.00
# act_participation  153.0      0.618824      0.334678      0.06      0.29
# act_english        153.0     20.953595      2.426743     16.30     19.00
# act_math           153.0     21.123529      2.027955     17.80     19.40
# act_reading        153.0     22.028758      2.149990     18.00     20.40
# act_science        153.0     21.373856      1.856028     17.90     19.90
# act_composite      153.0     21.493464      2.096321     17.70     19.80
# median_income      153.0  62594.797386  10831.440976  43469.00  55277.00
#
# ...

# %%
# Dictionary comprehension

sd = {feature : sd_dev(final[feature]) for feature in final.columns if final[feature].dtypes != object}

print(sd)
# Out:
# {'year': 0.816496580927726, 'sat_participation': 0.3697299717899723, 'sat_ebrw': 46.14980241905189, 'sat_math': 48.326661256683224, 'sat_total': 93.8544281331918, 'act_participation': 0.33358214474024833, 'act_english': 2.418799630557091, 'act_math': 2.0213166195789145, 'act_reading': 2.142952370699556, 'act_science': 1.8499521718541054, 'act_composite': 2.089459172687678, 'median_income': 10795.986081957648}

# %% [markdown]
# ### Which states have the highest and lowest ACT participation in the US for years 2017 - 2019?

# %%
max_act_participation = final.groupby(['year'])['act_participation'].max()
min_act_participation = final.groupby(['year'])['act_participation'].min()

# %%
display(max_act_participation)
display(min_act_participation)
# Out:
# year
# 2017    1.0
# 2018    1.0
# 2019    1.0
# Name: act_participation, dtype: float64
# year
# 2017    0.08
# 2018    0.07
# 2019    0.06
# Name: act_participation, dtype: float64

# %%
# Get highest and lowest participation rates for 2017 ACT

display(final[ (final['year'] == 2017) & (final['act_participation'] == max_act_participation[2017])].sort_values('state')[['state','act_participation']])
display(final[ (final['year'] == 2017) & (final['act_participation'] == min_act_participation[2017])].sort_values('state')[['state','act_participation']])
# Out:
#              state  act_participation
# 0          Alabama                1.0
# 3         Arkansas                1.0
# 5         Colorado                1.0
# 17        Kentucky                1.0
# 18       Louisiana                1.0
# 23       Minnesota                1.0
# 24     Mississippi                1.0
# 25        Missouri                1.0
# 26         Montana                1.0
# 28          Nevada                1.0
# 33  North Carolina                1.0
# 36        Oklahoma                1.0
# 40  South Carolina                1.0
# 42       Tennessee                1.0
# 44            Utah                1.0
# 49       Wisconsin                1.0
# 50         Wyoming                1.0
#     state  act_participation
# 19  Maine               0.08

# %%
# Get highest and lowest participation rates for 2018 ACT

display(final[ (final['year'] == 2018) & (final['act_participation'] == max_act_participation[2018])].sort_values('state')[['state','act_participation']])
display(final[ (final['year'] == 2018) & (final['act_participation'] == min_act_participation[2018])].sort_values('state')[['state','act_participation']])
# Out:
#               state  act_participation
# 51          Alabama                1.0
# 54         Arkansas                1.0
# 68         Kentucky                1.0
# 69        Louisiana                1.0
# 75      Mississippi                1.0
# 76         Missouri                1.0
# 77          Montana                1.0
# 78         Nebraska                1.0
# 79           Nevada                1.0
# 84   North Carolina                1.0
# 87             Ohio                1.0
# 86         Oklahoma                1.0
# 91   South Carolina                1.0
# 93        Tennessee                1.0
# 95             Utah                1.0
# 100       Wisconsin                1.0
# 101         Wyoming                1.0
#     state  act_participation
# 70  Maine               0.07

# %%
# Get highest and lowest participation rates for 2019 ACT

display(final[(final['year'] == 2019) & (final['act_participation'] == max_act_participation[2019])].sort_values('state')[['state','act_participation']])
display(final[(final['year'] == 2019) & (final['act_participation'] == min_act_participation[2019])].sort_values('state')[['state','act_participation']])
# Out:
#               state  act_participation
# 102         Alabama                1.0
# 105        Arkansas                1.0
# 119        Kentucky                1.0
# 120       Louisiana                1.0
# 126     Mississippi                1.0
# 128         Montana                1.0
# 129        Nebraska                1.0
# 130          Nevada                1.0
# 135  North Carolina                1.0
# 137            Ohio                1.0
# 138        Oklahoma                1.0
# 144       Tennessee                1.0
# 146            Utah                1.0
# 151       Wisconsin                1.0
# 152         Wyoming                1.0
#      state  act_participation
# 121  Maine               0.06

# %% [markdown]
# - Based on the above analysis:
#     - The common states where participation have been at the highest in 2017, 2018 and 2019 were Alabama, Arkansas, Kentucky, Louisiana, Mississipi, Montana, Nevada, North Carolina, Oklahoma, Tennessee, Utah, Wisconsin and Wyoming.
#     - The state of Maine had the lowerst participation rate in the ACT in years 2017 to 2019.
#     - Upon further online reserach, I discovered that a majority of the states with the highest participation were due to mandatory participation, with a minority of states like Ohio and Oklahoma allowing the district to decide if students take the ACT or SAT.
#     - Maine had the lowest participation rate across the years 2017 to 2019, due to the state having SAT as the compulsory test.
#     - Research links: https://blog.prepscholar.com/which-states-require-the-act-full-list-and-advice, https://testive.com/state-sat-act/.

# %% [markdown]
# ### Which states have the highest and lowest SAT participation in the US for years 2017 - 2019?

# %%
max_sat_participation = final.groupby(['year'])['sat_participation'].max()
min_sat_participation = final.groupby(['year'])['sat_participation'].min()

# %%
display(max_sat_participation)
display(min_sat_participation)
# Out:
# year
# 2017    1.0
# 2018    1.0
# 2019    1.0
# Name: sat_participation, dtype: float64
# year
# 2017    0.02
# 2018    0.02
# 2019    0.02
# Name: sat_participation, dtype: float64

# %%
# Get highest and lowest participation rates for 2017 SAT

display(final[(final['year'] == 2017) & (final['sat_participation'] == max_sat_participation[2017])].sort_values('state')[['state','sat_participation']])
display(final[(final['year'] == 2017) & (final['sat_participation'] == min_sat_participation[2017])].sort_values('state')[['state','sat_participation']])
# Out:
#                    state  sat_participation
# 6            Connecticut                1.0
# 7               Delaware                1.0
# 8   District of Columbia                1.0
# 22              Michigan                1.0
#            state  sat_participation
# 15          Iowa               0.02
# 24   Mississippi               0.02
# 34  North Dakota               0.02

# %%
# Get highest and lowest participation rates for 2018 SAT

display(final[(final['year'] == 2018) & (final['sat_participation'] == max_sat_participation[2018])].sort_values('state')[['state','sat_participation']])
display(final[(final['year'] == 2018) & (final['sat_participation'] == min_sat_participation[2018])].sort_values('state')[['state','sat_participation']])
# Out:
#           state  sat_participation
# 56     Colorado                1.0
# 57  Connecticut                1.0
# 58     Delaware                1.0
# 63        Idaho                1.0
# 73     Michigan                1.0
#            state  sat_participation
# 85  North Dakota               0.02

# %%
# Get highest and lowest participation rates for 2019 SAT

display(final[(final['year'] == 2019) & (final['sat_participation'] == max_sat_participation[2019])].sort_values('state')[['state','sat_participation']])
display(final[(final['year'] == 2019) & (final['sat_participation'] == min_sat_participation[2019])].sort_values('state')[['state','sat_participation']])
# Out:
#             state  sat_participation
# 107      Colorado                1.0
# 108   Connecticut                1.0
# 109      Delaware                1.0
# 111       Florida                1.0
# 114         Idaho                1.0
# 115      Illinois                1.0
# 124      Michigan                1.0
# 141  Rhode Island                1.0
#             state  sat_participation
# 136  North Dakota               0.02

# %% [markdown]
# - Based on the above analysis:
#     - The common states where participation have been at the highest in 2017, 2018 and 2019 were Colorado, Connecticut, Delaware, Florida and Michigan.
#     - The number of states with mandatory SAT is lower than that of states with mandatory ACT (SAT: 4 in 2017, 5 in 2018 and 8 in 2019. ACT: 17 in 2017, 2018 and 15 in 2019.)
#     - The state of North Dekota had the lowerst participation rate in the ACT in years 2017 to 2019.
#     - Similar to the ACT data, a majority of the states with the highest participation were due to mandatory participation. The states of Illinois and Rhode Island were added to the states requiring compulsory SAT from the 2017 - 2018 school year.
#     - North Dakota had the lowest participation rate across the years 2017 to 2019, due to the state having ACT as the compulsory test.
#     - Research links: https://blog.prepscholar.com/which-states-require-the-sat, https://testive.com/state-sat-act/.

# %% [markdown]
# ### Which states have the highest and lowest mean total/composite scores for the 2017, 2018, or 2019 ACT?

# %%
max_act_composite = final.groupby(['year'])['act_composite'].max()
min_act_composite = final.groupby(['year'])['act_composite'].min()

# %%
display(max_act_composite)
display(min_act_composite)
# Out:
# year
# 2017    25.5
# 2018    25.6
# 2019    25.5
# Name: act_composite, dtype: float64
# year
# 2017    17.8
# 2018    17.7
# 2019    17.9
# Name: act_composite, dtype: float64

# %%
# Get highest and lowest composite for 2017 ACT

display(final[ (final['year'] == 2017) & (final['act_composite'] == max_act_composite[2017])].sort_values('state')[['state','act_participation','act_english','act_math','act_reading','act_science','act_composite']])
display(final[ (final['year'] == 2017) & (final['act_composite'] == min_act_composite[2017])].sort_values('state')[['state','act_participation','act_english','act_math','act_reading','act_science','act_composite']])
# Out:
#             state  act_participation  act_english  act_math  act_reading  \
# 29  New Hampshire               0.18         25.4      25.1         26.0
#
#     act_science  act_composite
# 29         24.9           25.5
#      state  act_participation  act_english  act_math  act_reading  \
# 28  Nevada                1.0         16.3      18.0         18.1
#
#     act_science  act_composite
# 28         18.2           17.8

# %%
# Get highest and lowest composite for 2018 ACT

display(final[ (final['year'] == 2018) & (final['act_composite'] == max_act_composite[2018])].sort_values('state')[['state','act_participation','act_english','act_math','act_reading','act_science','act_composite']])
display(final[ (final['year'] == 2018) & (final['act_composite'] == min_act_composite[2018])].sort_values('state')[['state','act_participation','act_english','act_math','act_reading','act_science','act_composite']])
# Out:
#           state  act_participation  act_english  act_math  act_reading  \
# 57  Connecticut               0.26         26.0      24.8         26.1
#
#     act_science  act_composite
# 57         24.9           25.6
#      state  act_participation  act_english  act_math  act_reading  \
# 79  Nevada                1.0         16.6      17.8         18.0
#
#     act_science  act_composite
# 79         17.9           17.7

# %%
# Get highest and lowest composite for 2019 ACT

display(final[ (final['year'] == 2019) & (final['act_composite'] == max_act_composite[2019])].sort_values('state')[['state','act_participation','act_english','act_math','act_reading','act_science','act_composite']])
display(final[ (final['year'] == 2019) & (final['act_composite'] == min_act_composite[2019])].sort_values('state')[['state','act_participation','act_english','act_math','act_reading','act_science','act_composite']])
# Out:
#              state  act_participation  act_english  act_math  act_reading  \
# 108    Connecticut               0.22         25.9      24.7         26.1
# 123  Massachusetts               0.21         25.5      25.2         26.1
#
#      act_science  act_composite
# 108         24.8           25.5
# 123         24.8           25.5
#       state  act_participation  act_english  act_math  act_reading  \
# 130  Nevada                1.0         16.8      18.0         18.2
#
#      act_science  act_composite
# 130         17.9           17.9

# %% [markdown]
# - Based on the above analysis:
#     - New Hampshire had the highest composite score in 2017 and Connecticut had highest composite score in 2018 and 2019.
#     - Nevada had the lowest composite score in all three years.
#     - Interestingly, New Hampshire and Connecticut had relatively low participation rates in the years that they had the highest composite scores. The high composite scores could be due to a lower number of students taking the test as it is not compulsory to take the ACT in these states.

# %% [markdown]
# ### Which states have the highest and lowest mean total/composite scores for the 2017, 2018, or 2019 SAT?

# %%
max_sat_composite = final.groupby(['year'])['sat_total'].max()
min_sat_composite = final.groupby(['year'])['sat_total'].min()

# %%
display(max_sat_composite)
display(min_sat_composite)
# Out:
# year
# 2017    1295
# 2018    1298
# 2019    1284
# Name: sat_total, dtype: int64
# year
# 2017    950
# 2018    977
# 2019    943
# Name: sat_total, dtype: int64

# %%
# Get highest and lowest composite for 2017 SAT

display(final[(final['year'] == 2017) & (final['sat_total'] == max_sat_composite[2017])].sort_values('state')[['state','sat_participation','sat_ebrw','sat_math','sat_total']])
display(final[(final['year'] == 2017) & (final['sat_total'] == min_sat_composite[2017])].sort_values('state')[['state','sat_participation','sat_ebrw','sat_math','sat_total']])
# Out:
#         state  sat_participation  sat_ebrw  sat_math  sat_total
# 23  Minnesota               0.03       644       651       1295
#                   state  sat_participation  sat_ebrw  sat_math  sat_total
# 8  District of Columbia                1.0       482       468        950

# %%
# Get highest and lowest composite for 2018 SAT

display(final[(final['year'] == 2018) & (final['sat_total'] == max_sat_composite[2018])].sort_values('state')[['state','sat_participation','sat_ebrw','sat_math','sat_total']])
display(final[(final['year'] == 2018) & (final['sat_total'] == min_sat_composite[2018])].sort_values('state')[['state','sat_participation','sat_ebrw','sat_math','sat_total']])
# Out:
#         state  sat_participation  sat_ebrw  sat_math  sat_total
# 74  Minnesota               0.04       643       655       1298
#                    state  sat_participation  sat_ebrw  sat_math  sat_total
# 59  District of Columbia               0.92       497       480        977

# %%
# Get highest and lowest composite for 2019 SAT

display(final[(final['year'] == 2019) & (final['sat_total'] == max_sat_composite[2019])].sort_values('state')[['state','sat_participation','sat_ebrw','sat_math','sat_total']])
display(final[(final['year'] == 2019) & (final['sat_total'] == min_sat_composite[2019])].sort_values('state')[['state','sat_participation','sat_ebrw','sat_math','sat_total']])
# Out:
#          state  sat_participation  sat_ebrw  sat_math  sat_total
# 125  Minnesota               0.04       636       648       1284
#              state  sat_participation  sat_ebrw  sat_math  sat_total
# 150  West Virginia               0.99       483       460        943

# %% [markdown]
# - Based on the above analysis:
#     - Minnesota had the highest SAT total score in 2017, 2018 and 2019.
#     - District of Columbia had the lowest SAT total in Year 2017, 2018 and West Virginia had the lowest total score in 2019.
#     - A similar trend is noted whereby the states having the highest average scores are states that do not make the tests mandatory. The high total scores could be due to a lower number of students taking the test as it is not compulsory to take the SAT in these states.

# %% [markdown]
# ### Do any states have >50% on both tests each year?

# %%
final[(final['sat_participation'] > 0.5) & (final['act_participation'] > 0.5)][['state','year','sat_participation','act_participation']]
# Out:
#               state  year  sat_participation  act_participation
# 9           Florida  2017               0.83               0.73
# 10          Georgia  2017               0.61               0.55
# 11           Hawaii  2017               0.55               0.90
# 60          Florida  2018               0.56               0.66
# 61          Georgia  2018               0.70               0.53
# 62           Hawaii  2018               0.56               0.89
# 84   North Carolina  2018               0.52               1.00
# 91   South Carolina  2018               0.55               1.00
# 111         Florida  2019               1.00               0.54
# 113          Hawaii  2019               0.54               0.80
# 135  North Carolina  2019               0.51               1.00
# 142  South Carolina  2019               0.68               0.78

# %% [markdown]
# - Based on the above analysis:
#     - Florida and Hawaii have participation rates for SAT and ACT of above 50% in the years 2017 and 2018.
#     - North and South Carolina have participation rates above 50% in the years 2018 and 2019.
#     - It is noted that for states with compulsory ACT or SAT tests (participation of 100%), the participation rate for the alternative test is close to 50%.

# %% [markdown]
# ### Which are the states with the highest and lowest median income?

# %%
# Finding top 5 and bottom 5 of median income of the states for 2017

display(final[final['year'] == 2017].sort_values(by = 'median_income')[['state','year','median_income']].head())
display(final[final['year'] == 2017].sort_values(by = 'median_income')[['state','year','median_income']].tail())
# Out:
#             state  year  median_income
# 48  West Virginia  2017        43469.0
# 24    Mississippi  2017        43529.0
# 3        Arkansas  2017        45869.0
# 18      Louisiana  2017        46145.0
# 31     New Mexico  2017        46744.0
#                    state  year  median_income
# 21         Massachusetts  2017        77385.0
# 11                Hawaii  2017        77765.0
# 30            New Jersey  2017        80088.0
# 20              Maryland  2017        80776.0
# 8   District of Columbia  2017        82372.0

# %%
# Finding top 5 and bottom 5 of median income of the states for 2018

display(final[final['year'] == 2018].sort_values(by = 'median_income')[['state','year','median_income']].head())
display(final[final['year'] == 2018].sort_values(by = 'median_income')[['state','year','median_income']].tail())
# Out:
#             state  year  median_income
# 99  West Virginia  2018        44097.0
# 75    Mississippi  2018        44717.0
# 54       Arkansas  2018        47062.0
# 82     New Mexico  2018        47169.0
# 69      Louisiana  2018        47905.0
#                    state  year  median_income
# 72         Massachusetts  2018        79835.0
# 62                Hawaii  2018        80212.0
# 81            New Jersey  2018        81740.0
# 71              Maryland  2018        83242.0
# 59  District of Columbia  2018        85203.0

# %%
# Finding top 5 and bottom 5 of median income of the states for 2019

display(final[final['year'] == 2019].sort_values(by = 'median_income')[['state','year','median_income']].head())
display(final[final['year'] == 2019].sort_values(by = 'median_income')[['state','year','median_income']].tail())
# Out:
#              state  year  median_income
# 126    Mississippi  2019        45928.0
# 150  West Virginia  2019        48659.0
# 105       Arkansas  2019        49020.0
# 120      Louisiana  2019        51108.0
# 102        Alabama  2019        51771.0
#                     state  year  median_income
# 113                Hawaii  2019        83734.0
# 123         Massachusetts  2019        85700.0
# 132            New Jersey  2019        85786.0
# 122              Maryland  2019        86644.0
# 110  District of Columbia  2019        90395.0

# %% [markdown]
# - Based on the above analysis:
#     - States of Mississippi, West Virginia, Arkansas, Louisiana have the lowest median income for years 2017 - 2019.
#     - States of Hawaii, Massachusetts, New Jersey, Maryland and District of Columbia have highest median income for years 2017 - 2019.

# %% [markdown]
# **To-Do:** *Edit this cell with your findings on trends in the data (step 3 above).*

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# ### Visualising the Correlation Heatmap

# %%
plt.figure(figsize = (15,10))
plt.title('Correlation of features in final data',size = 25)

sns.heatmap(final.corr(), annot = True, vmin = -1, vmax = 1, linewidths = 0.1, cmap = 'rocket')
# Out:
# <AxesSubplot:title={'center':'Correlation of features in final data'}>

# %% [markdown]
# - Observations from heatmap:
#     - Both ACT and SAT participation rates are inversely correlated to their respective test results. This could suggest that students who take up tests that are not mandatory by state generally perform better than their counterparts, who do not have a choice of choosing which test to take.
#     - ACT subject results are highly correlated with each other, similarly with SAT results. This suggests that **students who do well in one subject tend to do well in the other subjects.**
#     - Median income seems to be moderately correlated to participation test participation, positively for SAT test and negatively for ACT test. However, median income is also moderately correlated to ACT test performances, suggesting **that students coming from wealthier families tend to achieve better results.**

# %% [markdown]
# ### Visualising histograms

# %%
# create a new df for participation rate by converting from long to wide
participation_rate_df = final[['state', 'year', 'act_participation','sat_participation']].pivot(index='state', columns='year', values=['act_participation','sat_participation'])
participation_rate_df.columns = [ '_'.join([str(c) for c in c_list]) for c_list in participation_rate_df.columns.values ]

participation_rate_df
# Out:
#                       act_participation_2017  act_participation_2018  \
# state
# Alabama                                 1.00                    1.00
# Alaska                                  0.65                    0.33
# Arizona                                 0.62                    0.66
# Arkansas                                1.00                    1.00
# California                              0.31                    0.27
# Colorado                                1.00                    0.30
# Connecticut                             0.31                    0.26
# Delaware                                0.18                    0.17
# District of Columbia                    0.32                    0.32
# Florida                                 0.73                    0.66
# Georgia                                 0.55                    0.53
# Hawaii                                  0.90                    0.89
# ...

# %%
# Function to visualise histograms

def subplot_histograms(data, columns_list, title_list, xlabels_list, sharex = False, kde = False, bins = 8, figsize = (13,10)):
    nrows = int(np.ceil(len(columns_list)/2))
    fig, ax = plt.subplots(nrows = nrows, ncols = 2, figsize = (13,10), sharex = sharex, sharey = True)
    ax = ax.ravel() # Turns matrix into vector, for easier iteration
    
    for i, column in enumerate(columns_list):
        mean = np.mean(data[columns_list[i]])
        ax[i].axvline(mean, ls = '--', color = 'red', label = 'mean')
        
        if 'act_' in column:
            color = 'blue'
        elif 'sat_' in column:
            color = 'orange'
            
        sns.histplot(data = data, x = column, ax = ax[i], kde = kde, bins = bins, color = color)
        ax[i].set_title(title_list[i])
        ax[i].set_xlabel(xlabels_list[i])

    fig.tight_layout()

# %%
participation = ['act_participation_2017','sat_participation_2017','act_participation_2018','sat_participation_2018',
                'act_participation_2019','sat_participation_2019']
titles = ['ACT participation 2017','SAT participation 2017','ACT participation 2018','SAT participation 2018',
         'ACT participation 2019','SAT participation 2019']
xlabels = ['Participation (%)','Participation (%)','Participation (%)','Participation (%)','Participation (%)','Participation (%)']

subplot_histograms(participation_rate_df, participation, titles, xlabels, sharex = True, kde = True)

# %% [markdown]
# - Observations from histogram:
#     - We see that the mean line for participation is moving towards the left for the ACT test and right for the SAT test, suggesting that states could be moving from the ACT test to adopting the SAT tests.
#     - The ACT tests have more states with low participation rate (below 50%) compared to SAT, which has more states with very high participation rate.

# %% [markdown]
# ### Visualising scatterplots

# %%
# Function for plotting scatterplots

def scatterplot(data, x, y, title):
    fig, ax = plt.subplots(figsize = (10,6))
    plt.title(title, size = 15)
    sns.regplot(data = data, y = y, x = x)
    plt.tight_layout()

# %%
scatterplot(participation_rate_df, 'sat_participation_2017','act_participation_2017','SAT Participation VS ACT Participation 2017')

plt.xlabel('SAT Participation Rate')
plt.ylabel('ACT Participation Rate')
# Out:
# Text(63.0, 0.5, 'ACT Participation Rate')

# %%
scatterplot(participation_rate_df, 'sat_participation_2018','act_participation_2018','SAT Participation VS ACT Participation 2018')

plt.xlabel('SAT Participation Rate')
plt.ylabel('ACT Participation Rate')
# Out:
# Text(63.0, 0.5, 'ACT Participation Rate')

# %%
scatterplot(participation_rate_df, 'sat_participation_2019','act_participation_2019','SAT Participation VS ACT Participation 2019')

plt.xlabel('SAT Participation Rate')
plt.ylabel('ACT Participation Rate')
# Out:
# Text(63.0, 0.5, 'ACT Participation Rate')

# %% [markdown]
# - Based on above analysis:
#     - We see that there is negative correlation between SAT participation and ACT participation. It is unlikely for students to take the SAT if they are already mandated to take the ACT, and vice versa.

# %%
scatterplot(final, 'sat_participation','sat_total','SAT Participation VS SAT Total Score')

plt.xlabel('SAT Participation Rate')
plt.ylabel('SAT Total Score')
# Out:
# Text(53.5, 0.5, 'SAT Total Score')

# %%
scatterplot(final, 'act_participation','act_composite','ACT Participation VS ACT Composite Score')

plt.xlabel('ACT Participation Rate')
plt.ylabel('ACT Composite Score')
# Out:
# Text(66.25, 0.5, 'ACT Composite Score')

# %% [markdown]
# - Observations from scatterplots above:
#     - We see that participation is negatively correlated to total score/ composite score. The higher the participation rates, the lower the mean scores of students. This could be due to a higher number of students taking tests that are mandatory by state, or it could suggest that students who opt to take optional tests to boost their chances of entering their school of choice, are working harder for the tests.

# %%
# Scatterplot for relationship between median income and SAT / ACT scores

scatterplot(final,'sat_total','median_income','Median income VS SAT Total Score')

plt.xlabel('SAT Total Score')
plt.ylabel('Median Income')
# Out:
# Text(47.125, 0.5, 'Median Income')

# %%
scatterplot(final,'act_composite','median_income','Median income VS ACT Composite Score')

plt.xlabel('ACT Composite Score',size = 15)
plt.ylabel('Median Income', size = 15)
# Out:
# Text(47.125, 0.5, 'Median Income')

# %% [markdown]
# - Observations from above scatterplots:
#     - We see a different pattern in relationship between median income level and SAT / ACT scores. In the SAT score scatterplot, it is noted that there is a slight negative correlation between median income and SAT score, whereas in the ACT score scatterplot, we see the reverse where a higher income level is moderately correlated with ACT score. This could suggest that families with higher median income view the ACT test more favourably and are willing to spend more to get their children to score well in it.

# %%
scatterplot(final,'sat_participation','median_income','Median income VS SAT Participation')

plt.xlabel('SAT Participation')
plt.ylabel('Median Income')
# Out:
# Text(47.125, 0.5, 'Median Income')

# %%
scatterplot(final,'act_participation','median_income','Median income VS ACT Participation')

plt.xlabel('ACT Participation')
plt.ylabel('Median Income')
# Out:
# Text(47.125, 0.5, 'Median Income')

# %% [markdown]
# - Observations from above scatterplots:
#     - We see a different pattern in relationship between median income level and SAT / ACT participation. In the SAT score scatterplot, it is noted that there is a moderately positive correlation between median income and SAT score, whereas in the ACT score scatterplot, we see the reverse where a higher income level is negatively correlated with ACT score. Moreoever, we see a cluster in the upper left of the ACT plot where households or states with higher median income participate in the ACT tests.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# Conclusion and key takeaways:
#
# - Median income is moderately positively correlated to ACT scores and negatively correlated to SAT scores.
# - Median income is moderately negatively correlated to ACT participation and positively correlated to SAT participation.
# - Students are likely to only take one type of test, either the SAT or ACT.
# - ACT is preferred over the SAT across the nation and states, but SAT growing in participation.
# - ACT / SAT scores are moderately inversely related to participation rate; the higher the participation rate, the lower the mean score of tests.

# %% [markdown]
# Recommendations to increase participation rate and mean test performances:
#
# - Offering test fee waivers to lower entry barrier of students from low-income families
# - Offering bursaries/grants to high achieving students from low-income families, especially states with mandatory ACT
# - Advocate for and support schools which strive to achieve equity of outcomes
# - Advocate for and support intervention programs that provide academic, social and community support to raise the success of disadvantaged children and youth
# - Increase student and family awareness of college accessibility
# - Train school staff to encourage and inculcate a 'college going' culture
# - Mandating completion of ACT / SAT for high school students
